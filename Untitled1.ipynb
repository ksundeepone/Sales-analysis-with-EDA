# %%
import pandas as pd

df = pd.read_csv('/Users/sundeep/Downloads/UTA/DATASETS/Life_Expectancy_Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from yellowbrick.features import rank2d


X = df[['Status', 'Hepatitis B']]  # Replace 'column1', 'column2', ... with the actual column names you want

# %%
from yellowbrick.features import Rank2D
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/sundeep/Downloads/UTA/DATASETS/Life_Expectancy_Data.csv')

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Extract the numeric features from the DataFrame
X = df[numeric_columns]

# Instantiate the Rank2D visualizer
visualizer = Rank2D(algorithm='pearson')  # You can change the algorithm as needed

# Fit and transform the data
visualizer.fit_transform(X)

# Display the visualization
visualizer.show()
# Out:
# <Axes: title={'center': 'Pearson Ranking of 20 Features'}>

# %%
from yellowbrick.features import rank1d
visualizer = rank1d(X, color="r")

# %%
from yellowbrick.features import parallel_coordinates
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/sundeep/Downloads/UTA/DATASETS/Life_Expectancy_Data.csv')

# Specify the target column (the one you want to predict)
target_column = 'Alcohol'

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Exclude the target column from features
numeric_columns = [col for col in numeric_columns if col != target_column]

# Extract features (X) and target (y)
X = df[numeric_columns]
y = df['Alcohol']

# Create and display the parallel coordinates visualization
visualizer = parallel_coordinates(X, y, normalize="standard")
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/yellowbrick/features/base.py:482, in DataVisualizer.get_colors(self, y)
#     478 try:
#     479     # Use the label encoder to get the class name (or use the value
#     480     # if the label is not mapped in the encoder) then use the class
#     481     # name to get the color from the color map.
# --> 482     return [self._colors[self._label_encoder.get(yi, yi)] for yi in y]
#     483 except KeyError:
#
# File ~/anaconda3/lib/python3.11/site-packages/yellowbrick/features/base.py:482, in <listcomp>(.0)
#     478 try:
#     479     # Use the label encoder to get the class name (or use the value
#     480     # if the label is not mapped in the encoder) then use the class
#     481     # name to get the color from the color map.
# ...

# %%
from yellowbrick.features import RadViz
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/sundeep/Downloads/UTA/DATASETS/Life_Expectancy_Data.csv')

# Assuming 'target_column' is the column you want to predict
target_column = 'Alcohol'

# Extract features (X) and target (y)
X = df.drop(target_column, axis=1)  # Exclude the target column from features
y = df['Alcohol']

# Create and display the RadViz visualization
visualizer = RadViz(colors=["maroon", "gold"])
visualizer.fit_transform(X, y)
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 16
#      14 # Create and display the RadViz visualization
#      15 visualizer = RadViz(colors=["maroon", "gold"])
# ---> 16 visualizer.fit_transform(X, y)
#      17 visualizer.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...

# %%
from yellowbrick.features import RadViz
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/sundeep/Downloads/UTA/DATASETS/Life_Expectancy_Data.csv')

# Assuming 'target_column' is the column you want to predict
target_column = 'Alcohol'

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Exclude the target column from features
numeric_columns = [col for col in numeric_columns if col != target_column]

# Extract features (X) and target (y)
X = df[numeric_columns]
y = df['Alcohol']

# Create and display the RadViz visualization
visualizer = RadViz(colors=["maroon", "gold"])
visualizer.fit_transform(X, y)
visualizer.show()
# Out:
# /Users/sundeep/anaconda3/lib/python3.11/site-packages/yellowbrick/utils/nan_warnings.py:78: DataWarning: Warning! Found 1289 rows of 2938 (43.87%) with nan values. Only complete rows will be plotted.
#   warnings.warn(warning_message, DataWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# ...
