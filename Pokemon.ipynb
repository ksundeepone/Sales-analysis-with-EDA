# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/sundeep/Downloads/pokemon_data.csv')
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
for index,row in df.iterrows():
    print(index, row['HP'] , row['Name'])
# Out:
# 0 45 Bulbasaur
# 1 60 Ivysaur
# 2 80 Venusaur
# 3 80 VenusaurMega Venusaur
# 4 39 Charmander
# 5 58 Charmeleon
# 6 78 Charizard
# 7 78 CharizardMega Charizard X
# 8 78 CharizardMega Charizard Y
# 9 44 Squirtle
# 10 59 Wartortle
# 11 79 Blastoise
# 12 79 BlastoiseMega Blastoise
# 13 45 Caterpie
# 14 50 Metapod
# 15 60 Butterfree
# 16 40 Weedle
# 17 45 Kakuna
# 18 65 Beedrill
# 19 65 BeedrillMega Beedrill
# 20 40 Pidgey
# 21 63 Pidgeotto
# 22 83 Pidgeot
# 23 83 PidgeotMega Pidgeot
# 24 30 Rattata
# 25 55 Raticate
# 26 40 Spearow
# 27 65 Fearow
# 28 35 Ekans
# 29 60 Arbok
# 30 35 Pikachu
# 31 60 Raichu
# 32 50 Sandshrew
# 33 75 Sandslash
# 34 55 Nidoran (Female)
# 35 70 Nidorina
# 36 90 Nidoqueen
# 37 46 Nidoran (Male)
# 38 61 Nidorino
# 39 81 Nidoking
# 40 70 Clefairy
# 41 95 Clefable
# 42 38 Vulpix
# 43 73 Ninetales
# 44 115 Jigglypuff
# 45 140 Wigglytuff
# 46 40 Zubat
# 47 75 Golbat
# 48 45 Oddish
# 49 60 Gloom
# 50 75 Vileplume
# 51 35 Paras
# 52 60 Parasect
# 53 60 Venonat
# ...

# %%
df.loc[df['Type 2']=='Poison']
#df.loc[df[]]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['HP'], ascending =False)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# Total          int64
# dtype: object

# %%
New_data = df.head(10)

# %%
New_data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
New_data['HP'].replace(45, pd.NA, inplace=True)
New_data.head()
# Out:
# /var/folders/ff/7cc6kw9n3m3fg2qb4y1mx5240000gn/T/ipykernel_43394/1123993630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data['HP'].replace(45, pd.NA, inplace=True)
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  <NA>      49       49       65
# 1  2                Ivysaur  Grass  Poison    60      62       63       80
# 2  3               Venusaur  Grass  Poison    80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison    80     100      123      122
# 4  4             Charmander   Fire     NaN    39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# ...

# %%
New_data.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  <NA>      49       49       65
# 1  2                Ivysaur  Grass  Poison    60      62       63       80
# 2  3               Venusaur  Grass  Poison    80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison    80     100      123      122
# 4  4             Charmander   Fire     NaN    39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
New_data.to_csv('modified.txt', index=False, sep = '\t')

# %%
New_data.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        3
# HP            1
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# Total         0
# dtype: int64

# %%
New_data.fillna(value = 'JILJIL', inplace = True)
New_data.head()
# Out:
# /var/folders/ff/7cc6kw9n3m3fg2qb4y1mx5240000gn/T/ipykernel_43394/1027538881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data.fillna(value = 'JILJIL', inplace = True)
#    #                   Name Type 1  Type 2      HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  JILJIL      49       49       65
# 1  2                Ivysaur  Grass  Poison      60      62       63       80
# 2  3               Venusaur  Grass  Poison      80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison      80     100      123      122
# 4  4             Charmander   Fire  JILJIL      39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# ...

# %%
New_data.replace('JILJIL', pd.NA, inplace= True)
New_data.head()
# Out:
# /var/folders/ff/7cc6kw9n3m3fg2qb4y1mx5240000gn/T/ipykernel_43394/3004705121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data.replace('JILJIL', pd.NA, inplace= True)
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  <NA>      49       49       65
# 1  2                Ivysaur  Grass  Poison    60      62       63       80
# 2  3               Venusaur  Grass  Poison    80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison    80     100      123      122
# 4  4             Charmander   Fire    <NA>    39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# ...

# %%
df.loc[(df['HP'] > 80) & (df['Defense'] >75)]
# Out:
#        #                 Name  Type 1    Type 2   HP  Attack  Defense  \
# 23    18  PidgeotMega Pidgeot  Normal    Flying   83      80       80
# 36    31            Nidoqueen  Poison    Ground   90      92       87
# 39    34             Nidoking  Poison    Ground   81     102       77
# 64    59             Arcanine    Fire       NaN   90     110       80
# 67    62            Poliwrath   Water  Fighting   90      95       95
# ..   ...                  ...     ...       ...  ...     ...      ...
# 789  713              Avalugg     Ice       NaN   95     117      184
# 791  715              Noivern  Flying    Dragon   85      70       80
# 792  716              Xerneas   Fairy       NaN  126     131       95
# 793  717              Yveltal    Dark    Flying  126     131       95
# 794  718     Zygarde50% Forme  Dragon    Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 23       135       80    121           1      False    579
# ...

# %%
df.loc[df['Type 1'].str.contains('son')]
# Out:
#        #              Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 28    23             Ekans  Poison       NaN   35      60       44       40
# 29    24             Arbok  Poison       NaN   60      85       69       65
# 34    29  Nidoran (Female)  Poison       NaN   55      47       52       40
# 35    30          Nidorina  Poison       NaN   70      62       67       55
# 36    31         Nidoqueen  Poison    Ground   90      92       87       75
# 37    32    Nidoran (Male)  Poison       NaN   46      57       40       40
# 38    33          Nidorino  Poison       NaN   61      72       57       55
# 39    34          Nidoking  Poison    Ground   81     102       77       85
# 46    41             Zubat  Poison    Flying   40      45       35       30
# 47    42            Golbat  Poison    Flying   75      80       70       65
# 95    88            Grimer  Poison       NaN   80      80       50       40
# ...

# %%
df.loc[df['Type 2']=='Poison', 'Type 2'] = 'Martin Garrix'
df.head()
# Out:
#    #                   Name Type 1         Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Martin Garrix  45      49       49
# 1  2                Ivysaur  Grass  Martin Garrix  60      62       63
# 2  3               Venusaur  Grass  Martin Garrix  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Martin Garrix  80     100      123
# 4  4             Charmander   Fire         JILJIL  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0       65       65     45           1      False    318
# 1       80       80     60           1      False    405
# 2      100      100     80           1      False    525
# 3      122      120     80           1      False    625
# 4       60       50     65           1      False    309

# %%
df.loc[(df['Type 2']=='Martin Garrix') & (df['HP']> 60)]
# Out:
#        #                   Name Type 1         Type 2   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Martin Garrix   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Martin Garrix   80     100      123
# 18    15               Beedrill    Bug  Martin Garrix   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Martin Garrix   65     150       40
# 50    45              Vileplume  Grass  Martin Garrix   75      80       85
# 54    49               Venomoth    Bug  Martin Garrix   70      65       60
# 76    70             Weepinbell  Grass  Martin Garrix   65      90       50
# 77    71             Victreebel  Grass  Martin Garrix   80     105       65
# 79    73             Tentacruel  Water  Martin Garrix   80      70       65
# 182  168                Ariados    Bug  Martin Garrix   70      90       70
# 227  211               Qwilfish  Water  Martin Garrix   65      95       75
# ...

# %%
df.loc[(df['HP'] > 80) & (df['Defense'] >75)]
# Out:
#        #                 Name  Type 1    Type 2   HP  Attack  Defense  \
# 23    18  PidgeotMega Pidgeot  Normal    Flying   83      80       80
# 36    31            Nidoqueen  Poison    Ground   90      92       87
# 39    34             Nidoking  Poison    Ground   81     102       77
# 64    59             Arcanine    Fire       NaN   90     110       80
# 67    62            Poliwrath   Water  Fighting   90      95       95
# ..   ...                  ...     ...       ...  ...     ...      ...
# 789  713              Avalugg     Ice       NaN   95     117      184
# 791  715              Noivern  Flying    Dragon   85      70       80
# 792  716              Xerneas   Fairy       NaN  126     131       95
# 793  717              Yveltal    Dark    Flying  126     131       95
# 794  718     Zygarde50% Forme  Dragon    Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 23       135       80    121           1      False    579
# ...

# %%
df.loc[df['HP']>43, 'Generation'] = 'YAY'
df.head()
# Out:
#    #                   Name Type 1         Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Martin Garrix  45      49       49
# 1  2                Ivysaur  Grass  Martin Garrix  60      62       63
# 2  3               Venusaur  Grass  Martin Garrix  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Martin Garrix  80     100      123
# 4  4             Charmander   Fire         JILJIL  39      52       43
#
#    Sp. Atk  Sp. Def  Speed Generation  Legendary  Total
# 0       65       65     45        YAY      False    318
# 1       80       80     60        YAY      False    405
# 2      100      100     80        YAY      False    525
# 3      122      120     80        YAY      False    625
# 4       60       50     65          1      False    309

# %%
df.loc[df['Generation']=='YAY']
# Out:
#        #                   Name   Type 1         Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Martin Garrix  45      49       49
# 1      2                Ivysaur    Grass  Martin Garrix  60      62       63
# 2      3               Venusaur    Grass  Martin Garrix  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Martin Garrix  80     100      123
# 5      5             Charmeleon     Fire         JILJIL  58      64       58
# ..   ...                    ...      ...            ...  ..     ...      ...
# 795  719                Diancie     Rock          Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock          Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic          Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic           Dark  80     160       60
# 799  721              Volcanion     Fire          Water  80     110      120
#
# ...

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.groupby(['Defense']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
df['Defense'] = pd.to_numeric(df['Defense'], errors='coerce')
mean = df.groupby(['Defense']).mean()

mean
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...
