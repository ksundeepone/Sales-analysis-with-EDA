# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/Users/sundeep/Downloads/sales_data/Sales_April_2019.csv")
df2 = pd.read_csv("/Users/sundeep/Downloads/sales_data/Sales_August_2019.csv")

# %%
    df1.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df2.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %%
data = pd.concat([df1, df2], ignore_index = True)

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
data.isnull().sum()
# Out:
# Order ID            87
# Product             87
# Quantity Ordered    87
# Price Each          87
# Order Date          87
# Purchase Address    87
# dtype: int64

# %%
data.dropna(how='all', inplace = True)

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data['Order ID'] = pd.to_numeric(data['Order ID'], errors = 'coerce')

data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'], errors = 'coerce')

data['Price Each'] = pd.to_numeric(data['Price Each'], errors = 'coerce')

#data['Order Date'] = pd.to_numeric(data['Order Date'], errors = 'coerce')

# %%
data['Order ID'] = data['Order ID'].astype('Int32')
data['Quantity Ordered'] = data['Quantity Ordered'].astype('Int32')

# %%
data.dtypes
# Out:
# Order ID              Int32
# Product              object
# Quantity Ordered      Int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
data['month'] = data['Order Date'].str[0:2]
#data['day'] = data['Order Date'].dt.day
#data['year'] = data['Order Date'].dt.year

# %%
data['month'] = data['month'].astype('Int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data['month'] = data['month'].astype('Int32')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
find_or = data[data['Order Date'].str[0:2] == 'Or']
find_or.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519       <NA>  Product              <NA>         NaN  Order Date
# 1149      <NA>  Product              <NA>         NaN  Order Date
# 1155      <NA>  Product              <NA>         NaN  Order Date
# 2878      <NA>  Product              <NA>         NaN  Order Date
# 2893      <NA>  Product              <NA>         NaN  Order Date
#
#       Purchase Address month  Sales
# 519   Purchase Address    Or   <NA>
# 1149  Purchase Address    Or   <NA>
# 1155  Purchase Address    Or   <NA>
# 2878  Purchase Address    Or   <NA>
# 2893  Purchase Address    Or   <NA>

# %%
find_or_alt = data[data['Order Date'].str.contains('Or')]
find_or_alt
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519        <NA>  Product              <NA>         NaN  Order Date
# 1149       <NA>  Product              <NA>         NaN  Order Date
# 1155       <NA>  Product              <NA>         NaN  Order Date
# 2878       <NA>  Product              <NA>         NaN  Order Date
# 2893       <NA>  Product              <NA>         NaN  Order Date
# ...         ...      ...               ...         ...         ...
# 27988      <NA>  Product              <NA>         NaN  Order Date
# 28600      <NA>  Product              <NA>         NaN  Order Date
# 28721      <NA>  Product              <NA>         NaN  Order Date
# 29088      <NA>  Product              <NA>         NaN  Order Date
# 29387      <NA>  Product              <NA>         NaN  Order Date
#
#        Purchase Address month  Sales
# 519    Purchase Address    Or   <NA>
# 1149   Purchase Address    Or   <NA>
# 1155   Purchase Address    Or   <NA>
# ...

# %%
data = data[data['Order Date'].str[0:2]!= 'Or']
data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 30389    248146  Bose SoundSport Headphones                 1       99.99
# 30390    248147      AAA Batteries (4-pack)                 3        2.99
# 30391    248148       AA Batteries (4-pack)                 1        3.84
# 30392    248149        USB-C Charging Cable                 1       11.95
# 30393    248150       AA Batteries (4-pack)                 1        3.84
#
#            Order Date                         Purchase Address month  Sales
# ...

# %%
data['month'] = data['month'].astype('Int32')

# %%
#data['month'] = pd.to_numeric(data['month'], errors = 'coerce')
#data['day'] = pd.to_numeric(data['day'], errors = 'coerce')
#data['year'] = pd.to_numeric(data['year'], errors = 'coerce')

#data['month'] = data['month'].astype('Int32')
#data['day'] = data['day'].astype('Int32')
#data['year'] = data['year'].astype('Int32')

# %%
data.dtypes
# Out:
# Order ID              Int32
# Product              object
# Quantity Ordered      Int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# month                 Int32
# Sales               Float64
# dtype: object

# %%
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  month  Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.9
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4  99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.0
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4  11.99

# %%
data['Sales'] = data['Quantity Ordered'] * data['Price Each']

data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  month  Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.9
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4  99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.0
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4  11.99

# %%
data.groupby('month').sum()
# Out:
#          Order ID                                            Product  \
# month
# 4      3384310980  USB-C Charging CableBose SoundSport Headphones...
# 5         5167749  Apple Airpods Headphones27in FHD MonitoriPhone...
# 8      2895702448  Wired HeadphonesBose SoundSport HeadphonesiPho...
# 9         2917549  Apple Airpods Headphones34in Ultrawide Monitor...
#
#        Quantity Ordered  Price Each  \
# month
# 4                 20539  3362503.59
# 5                    29    10555.45
# 8                 13430  2228199.94
# 9                    12     2096.74
#
#                                               Order Date  \
# month
# 4      04/19/19 08:4604/07/19 22:3004/12/19 14:3804/1...
# 5      05/01/19 03:2905/01/19 00:1305/01/19 00:4805/0...
# 8      08/31/19 22:2108/15/19 15:1108/06/19 14:4008/2...
# 9      09/01/19 04:1309/01/19 01:0909/01/19 02:0709/0...
#
#                                         Purchase Address       Sales
# month
# ...
